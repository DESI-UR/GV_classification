# %% [markdown]
# # Plots for SDSS GV paper

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from astropy.table import Table, join
from tqdm import tqdm

# %%
matplotlib.rcParams['figure.dpi'] = 100
matplotlib.rcParams['savefig.dpi'] = 300

# %% [markdown]
# ## load data

# %%
DATA_FOLDER = '/pscratch/sd/n/nravi/GV_classification/'

# %%
nsa = Table.read(DATA_FOLDER + 'nsa_v1_0_1_cd_v4_cinv.fits')

# %%
nsa_dict = {}
for i in range(len(nsa)):

    nsa_dict[nsa['IAUNAME'][i]] = i

# %%
nsa[:5]
# Out:
# <Table length=5>
#       IAUNAME                  SUBDIR           ...         cinv
#       bytes19                 bytes27           ...       float64
# ------------------- --------------------------- ... -------------------
# J094651.40-010228.5 09h/m00/J094651.40-010228.5 ... 0.20500519450176555
# J094630.85-004554.5 09h/m00/J094630.85-004554.5 ...                  --
# J094631.59-005917.7 09h/m00/J094631.59-005917.7 ...                  --
# J094744.18-004013.4 09h/m00/J094744.18-004013.4 ... 0.06217369781559782
# J094751.74-003242.0 09h/m00/J094751.74-003242.0 ...                  --
