# %% [markdown]
# # compare cd for NSA and KIAS w version 2 of fitting (cog restricted to < 2R90, init guesses)

# %%
from astropy.table import Table, vstack, hstack
import numpy as np
import numpy.ma as ma
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib as mpl

from IPython.display import Image

from color_gradient_functions import pogson_mag_from_flux, extract_cog_data, SGA_cog

from scipy.optimize import curve_fit, minimize

# %% [markdown]
# ## load tables

# %%
DATA_FOLDER = '/pscratch/sd/n/nravi/GV_classification/'

# %%
kias = Table.read(DATA_FOLDER + 'NSA_v1_0_1_vflag_Portsmouth.fits')

# %% [markdown]
# ## create nsa table from subtables

# %%
nsa = Table.read(DATA_FOLDER + 'nsa_v1_0_1_cd_0_5831.fits')
for i in tqdm(np.arange(5831, 641410, 5831)):

    tmp_table = Table.read(DATA_FOLDER + 'nsa_v1_0_1_cd_' + str(i) + '_' + str(i+5831) + '.fits')
    nsa = vstack([nsa, tmp_table])
# Out:
# 100%|██████████| 109/109 [02:45<00:00,  1.52s/it]

# %%
nsa.write(DATA_FOLDER + 'nsa_v1_0_1_cd_v3.fits')

# %% [markdown]
# ## read in nsa table

# %%
nsa = Table.read(DATA_FOLDER + 'nsa_v1_0_1_cd_v3.fits')

# %%
nsa[:5]
# Out:
# <Table length=5>
#       IAUNAME                  SUBDIR           ...         NSA_cd
#       bytes19                 bytes27           ...        float64
# ------------------- --------------------------- ... ---------------------
# J094651.40-010228.5 09h/m00/J094651.40-010228.5 ...  -0.16870439124573022
# J094630.85-004554.5 09h/m00/J094630.85-004554.5 ...  -0.17999153685622027
# J094631.59-005917.7 09h/m00/J094631.59-005917.7 ...   0.07087241902615643
# J094744.18-004013.4 09h/m00/J094744.18-004013.4 ... -0.041985880084193905
# J094751.74-003242.0 09h/m00/J094751.74-003242.0 ...                    --

# %%
nsa_dict = {}
for i in range(len(nsa)):

    nsa_dict[nsa['IAUNAME'][i]] = i

# %%
nsa['kias_cd'] = np.ones(len(nsa))**np.nan

# %%
for i in tqdm(range(len(kias))):

    iauname = kias['IAUNAME'][i]
    i_nsa = nsa_dict[iauname]

    nsa['kias_cd'][i_nsa] = kias['cd'][i]
# Out:
# 100%|██████████| 641409/641409 [00:04<00:00, 159366.83it/s]

# %% [markdown]
# ## compare cd values

# %%
plt.scatter(nsa['NSA_cd'], nsa['kias_cd'], 
          alpha=0.1, marker='.', )
           # bins=100, 
           #range=[[-1, 1], [-5, 5]], 
           # norm=mpl.colors.LogNorm())
plt.xlabel(r'NSA $\Delta (g-i)$')
plt.ylabel(r'KIAS $\Delta (g-i)$')
# Out:
# Text(0, 0.5, 'KIAS $\\Delta (g-i)$')

# %%
plt.hist2d(nsa['NSA_cd'], nsa['kias_cd'], 
          # alpha=0.1, marker='.', 
           bins=100, 
           range=[[-5, 5], [-5, 5]], 
           norm=mpl.colors.LogNorm())
plt.xlabel(r'NSA $\Delta (g-i)$')
plt.ylabel(r'KIAS $\Delta (g-i)$')
# plt.plot([-1,1],[-1,1], color='r', linewidth=2)
plt.colorbar(label='number of galaxies')

# %%
plt.hist2d(nsa['NSA_cd'], nsa['kias_cd'], 
          # alpha=0.1, marker='.', 
           bins=100, 
           range=[[-1, 1], [-1, 1]], 
           norm=mpl.colors.LogNorm())
plt.xlabel(r'NSA $\Delta (g-i)$')
plt.ylabel(r'KIAS $\Delta (g-i)$')
plt.plot([-1,1],[-1,1], color='r', linewidth=2)
plt.colorbar(label='number of galaxies')

# %%
nsa_highcd = nsa[nsa['NSA_cd'] > 2]
nsa_highcd[:5]
# Out:
# <Table length=5>
#       IAUNAME                  SUBDIR           ...       NSA_cd       kias_cd
#       bytes19                 bytes27           ...      float64       float64
# ------------------- --------------------------- ... ------------------ -------
# J111658.75-002116.9 11h/m00/J111658.75-002116.9 ... 2.4285523843493446  -0.331
# J114948.02+002715.2 11h/p00/J114948.02+002715.2 ... 3.2252244471397478   -99.0
# J115909.13+002940.0 11h/p00/J115909.13+002940.0 ... 2.1399132788315063  -0.186
# J141438.65+002839.0 14h/p00/J141438.65+002839.0 ... 2.0402557422970915   -99.0
# J154355.87+003511.5 15h/p00/J154355.87+003511.5 ... 2.5470980303706785   -99.0

# %%
Image(DATA_FOLDER + '/cog_plots/' + str(nsa_highcd['IAUNAME'][1]) + '.png')

# %% [markdown]
# ## should scale radius be a free param

# %%
SGA_2020_fn = '/global/cfs/cdirs/cosmo/data/sga/2020/SGA-2020.fits'
SGA_2020 = Table.read(SGA_2020_fn, hdu='ELLIPSE')
SGA_2020[:5]
# Out:
# <Table length=5>
# SGA_ID  SGA_GALAXY          GALAXY         ... Z_COG_PARAMS_CHI2 ELLIPSEBIT
# int64    bytes16           bytes29         ...      float32        int32
# ------ ----------- ----------------------- ... ----------------- ----------
#      2  SGA-2020 2              PGC1283207 ...       0.011723555          0
#      3  SGA-2020 3              PGC1310416 ...        0.20391206          0
#      4  SGA-2020 4 SDSSJ145059.93+135143.0 ...         1.8054093          0
#      7  SGA-2020 7              PGC1742504 ...       0.004725194          0
#     18 SGA-2020 18  2MASXJ12340801+4535444 ...       0.028653827          0

# %%
plt.hist(SGA_2020['Z_LEDA'][SGA_2020['Z_LEDA'] > -99], bins=np.linspace(-1,1,100))
# Out:
# (array([2.8890e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 7.2110e+03,
#         3.9753e+04, 5.9526e+04, 5.7320e+04, 4.4602e+04, 2.4103e+04,
#         1.5332e+04, 8.6200e+03, 4.0530e+03, 2.0820e+03, 1.0400e+03,
#         5.5700e+02, 2.6100e+02, 1.3200e+02, 8.0000e+01, 5.4000e+01,
#         2.6000e+01, 1.6000e+01, 1.3000e+01, 1.3000e+01, 3.0000e+00,
#         3.0000e+00, 3.0000e+00, 1.0000e+00, 7.0000e+00, 4.0000e+00,
#         6.0000e+00, 0.0000e+00, 3.0000e+00, 1.0000e+00, 2.0000e+00,
#         2.0000e+00, 2.0000e+00, 2.0000e+00, 1.0000e+00, 1.0000e+00,
#         2.0000e+00, 3.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00,
#         1.0000e+00, 2.0000e+00, 0.0000e+00, 3.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00]),
#  array([-1.        , -0.97979798, -0.95959596, -0.93939394, -0.91919192,
#         -0.8989899 , -0.87878788, -0.85858586, -0.83838384, -0.81818182,
#         -0.7979798 , -0.77777778, -0.75757576, -0.73737374, -0.71717172,
#         -0.6969697 , -0.67676768, -0.65656566, -0.63636364, -0.61616162,
#         -0.5959596 , -0.57575758, -0.55555556, -0.53535354, -0.51515152,
#         -0.49494949, -0.47474747, -0.45454545, -0.43434343, -0.41414141,
#         -0.39393939, -0.37373737, -0.35353535, -0.33333333, -0.31313131,
#         -0.29292929, -0.27272727, -0.25252525, -0.23232323, -0.21212121,
#         -0.19191919, -0.17171717, -0.15151515, -0.13131313, -0.11111111,
#         -0.09090909, -0.07070707, -0.05050505, -0.03030303, -0.01010101,
#          0.01010101,  0.03030303,  0.05050505,  0.07070707,  0.09090909,
#          0.11111111,  0.13131313,  0.15151515,  0.17171717,  0.19191919,
#          0.21212121,  0.23232323,  0.25252525,  0.27272727,  0.29292929,
#          0.31313131,  0.33333333,  0.35353535,  0.37373737,  0.39393939,
#          0.41414141,  0.43434343,  0.45454545,  0.47474747,  0.49494949,
#          0.51515152,  0.53535354,  0.55555556,  0.57575758,  0.5959596 ,
#          0.61616162,  0.63636364,  0.65656566,  0.67676768,  0.6969697 ,
#          0.71717172,  0.73737374,  0.75757576,  0.77777778,  0.7979798 ,
#          0.81818182,  0.83838384,  0.85858586,  0.87878788,  0.8989899 ,
#          0.91919192,  0.93939394,  0.95959596,  0.97979798,  1.        ]),
#  <BarContainer object of 99 artists>)

# %%
plt.hist(nsa['Z'])
# Out:
# (array([  7729.,  31106.,  55248.,  64073.,  81723., 101142.,  78702.,
#          81639.,  74686.,  65361.]),
#  array([-0.00448154,  0.01096657,  0.02641468,  0.04186279,  0.0573109 ,
#          0.07275901,  0.08820712,  0.10365523,  0.11910334,  0.13455145,
#          0.14999956]),
#  <BarContainer object of 10 artists>)
